# %% [markdown]
# <a href="https://colab.research.google.com/github/sipocz/yokodok/blob/main/Yokodok_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
url="https://github.com/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html"

# %%
# !wget $url
# Out:
# --2022-06-23 18:31:43--  https://github.com/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html
# Resolving github.com (github.com)... 13.114.40.48
# Connecting to github.com (github.com)|13.114.40.48|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: unspecified [text/html]
# Saving to: ‘Library _ Yokogawa Electric Corporation.html’
#
# Library _ Yokogawa      [ <=>                ] 131.59K  --.-KB/s    in 0.1s
#
# 2022-06-23 18:31:43 (1.05 MB/s) - ‘Library _ Yokogawa Electric Corporation.html’ saved [134752]

# %%
import requests
from bs4 import  BeautifulSoup



def query():
    
    url="./Library _ Yokogawa Electric Corporation.html"
    file=open(url)
    res=file.read()
    #print(res)
    soup=BeautifulSoup(res,"html.parser")
    urllist=soup.find_all("div")
    print(urllist)

    print("----------------  END  ------------------------")

# %%
query()
# Out:
# [<div class="position-relative js-header-wrapper ">
# <a class="px-2 py-4 color-bg-accent-emphasis color-fg-on-emphasis show-on-focus js-skip-to-content" href="#start-of-content">Skip to content</a>
# <span class="progress-pjax-loader js-pjax-loader-bar Progress position-fixed width-full" data-view-component="true">
# <span class="Progress-item progress-pjax-loader-bar left-0 top-0 color-bg-accent-emphasis" data-view-component="true" style="width: 0%;"></span>
# </span>
# <script crossorigin="anonymous" defer="defer" integrity="sha512-jlW5xrOJi/1OVMQxY+2JSZYLF9CDrwW1KJsRA61YG9H/ea+vpb6ZvqlS0ZDhrcUjkGE1m3KiWNsAf+Z8GdlWCA==" src="https://github.githubassets.com/assets/sessions-8e55b9c6b389.js" type="application/javascript"></script>
# <header class="Header-old header-logged-out js-details-container Details position-relative f4 py-2" role="banner">
# <div class="container-xl d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html","user_id":null}}' data-hydro-click-hmac="09641b40d6cfd6fece46f1b1578c7425694af966f4aa852ad983e6b8616d3ee7" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2F%3Cuser-name%3E%2F%3Crepo-name%3E%2Fblob%2Fshow&amp;source=header-repo">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Product
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Features;"}' href="/features">
#       Features
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Mobile;"}' href="/mobile">
#       Mobile
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Actions;"}' href="/features/actions">
#       Actions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Codespaces;"}' href="/features/codespaces">
#       Codespaces
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Copilot;"}' href="/features/copilot">
#       Copilot
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Packages;"}' href="/features/packages">
#       Packages
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Security;"}' href="/features/security">
#       Security
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Code review;"}' href="/features/code-review">
#       Code review
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Issues;"}' href="/features/issues">
#       Issues
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Integrations","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Integrations;"}' href="/features/integrations">
#       Integrations
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Sponsors","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:GitHub Sponsors;"}' href="/sponsors">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Customer stories","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Customer stories;"}' href="/customer-stories">
#       Customer stories
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Team","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Team;"}' href="/team">Team</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Enterprise","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Enterprise;"}' href="/enterprise">Enterprise</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Explore
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Explore GitHub","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Explore GitHub;"}' href="/explore">
#       Explore GitHub
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Learn and contribute</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Topics","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Topics;"}' href="/topics">
#       Topics
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Collections","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Collections;"}' href="/collections">
#       Collections
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Trending","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Trending;"}' href="/trending">
#       Trending
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Skills","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Skills;"}' href="https://skills.github.com/">
#       Skills
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Sponsors","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:GitHub Sponsors;"}' href="/sponsors/explore">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Open source guides","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Open source guides;"}' href="https://opensource.guide">
#       Open source guides
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Connect with others</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to The ReadME Project","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:The ReadME Project;"}' href="/readme">
#       The ReadME Project
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Events","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Events;"}' href="/events">
#       Events
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Community forum","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Community forum;"}' href="https://github.community">
#       Community forum
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Education","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:GitHub Education;"}' href="https://education.github.com">
#       GitHub Education
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Stars program","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:GitHub Stars program;"}' href="https://stars.github.com">
#       GitHub Stars program
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Marketplace","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Marketplace;"}' href="/marketplace">Marketplace</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Pricing
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Plans","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Plans;"}' href="/pricing">
#       Plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Compare plans","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Compare plans;"}' href="/pricing#compare-features">
#       Compare plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Contact Sales","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Contact Sales;"}' href="https://github.com/enterprise/contact">
#       Contact Sales
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Education","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Education;"}' href="https://education.github.com">
#       Education
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex min-width-0 mb-3 mb-lg-0">
# <div class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --></div></div></div></div></div></div></header></div>, <div class="container-xl d-lg-flex flex-items-center p-responsive">
# <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html","user_id":null}}' data-hydro-click-hmac="09641b40d6cfd6fece46f1b1578c7425694af966f4aa852ad983e6b8616d3ee7" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2F%3Cuser-name%3E%2F%3Crepo-name%3E%2Fblob%2Fshow&amp;source=header-repo">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>
# <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Product
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Features;"}' href="/features">
#       Features
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Mobile;"}' href="/mobile">
#       Mobile
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Actions;"}' href="/features/actions">
#       Actions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Codespaces;"}' href="/features/codespaces">
#       Codespaces
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Copilot;"}' href="/features/copilot">
#       Copilot
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Packages","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Packages;"}' href="/features/packages">
#       Packages
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Security","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Security;"}' href="/features/security">
#       Security
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Code review","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Code review;"}' href="/features/code-review">
#       Code review
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Issues","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Issues;"}' href="/features/issues">
#       Issues
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Integrations","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Integrations;"}' href="/features/integrations">
#       Integrations
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to GitHub Sponsors","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:GitHub Sponsors;"}' href="/sponsors">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Customer stories","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Customer stories;"}' href="/customer-stories">
#       Customer stories
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Team","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Team;"}' href="/team">Team</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Enterprise","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Enterprise;"}' href="/enterprise">Enterprise</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Explore
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Explore GitHub","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Explore GitHub;"}' href="/explore">
#       Explore GitHub
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Learn and contribute</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Topics","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Topics;"}' href="/topics">
#       Topics
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Collections","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Collections;"}' href="/collections">
#       Collections
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Trending","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Trending;"}' href="/trending">
#       Trending
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Skills","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Skills;"}' href="https://skills.github.com/">
#       Skills
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Sponsors","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:GitHub Sponsors;"}' href="/sponsors/explore">
#       GitHub Sponsors
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Open source guides","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Open source guides;"}' href="https://opensource.guide">
#       Open source guides
# </a> </li>
# <li class="color-fg-muted text-normal f6 text-mono mb-1 border-top pt-3 mt-3 mb-1">Connect with others</li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to The ReadME Project","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:The ReadME Project;"}' href="/readme">
#       The ReadME Project
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Events","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Events;"}' href="/events">
#       Events
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to Community forum","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Community forum;"}' href="https://github.community">
#       Community forum
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Education","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:GitHub Education;"}' href="https://education.github.com">
#       GitHub Education
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Explore","action":"click to go to GitHub Stars program","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:GitHub Stars program;"}' href="https://stars.github.com">
#       GitHub Stars program
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <a class="HeaderMenu-link no-underline py-3 d-block d-lg-inline-block" data-analytics-event='{"category":"Header menu top item (logged out)","action":"click to go to Marketplace","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Marketplace;"}' href="/marketplace">Marketplace</a>
# </li>
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Pricing
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Plans","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Plans;"}' href="/pricing">
#       Plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Compare plans","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Compare plans;"}' href="/pricing#compare-features">
#       Compare plans
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Contact Sales","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Contact Sales;"}' href="https://github.com/enterprise/contact">
#       Contact Sales
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold border-top pt-4 pb-2 mt-3" data-analytics-event='{"category":"Header dropdown (logged out), Pricing","action":"click to go to Education","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Education;"}' href="https://education.github.com">
#       Education
# </a> </li>
# </ul>
# </div>
# </details>
# </li>
# </ul>
# </nav>
# <div class="d-lg-flex flex-items-center px-3 px-lg-0 text-center text-lg-left">
# <div class="d-lg-flex min-width-0 mb-3 mb-lg-0">
# <div class="header-search flex-auto js-site-search position-relative flex-self-stretch flex-md-self-auto mb-3 mb-md-0 mr-0 mr-md-3 scoped-search site-scoped-search js-jump-to">
# <div class="position-relative">
# <!-- '"` --><!-- </textarea></xmp> --></div></div></div></div></div></div>, <div class="d-flex flex-justify-between flex-items-center">
# <a aria-label="Homepage" class="mr-4 color-fg-inherit" data-ga-click="(Logged out) Header, go to homepage, icon:logo-wordmark" href="https://github.com/">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="32" version="1.1" viewbox="0 0 16 16" width="32">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a>
# <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>
# <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html","user_id":null}}' data-hydro-click-hmac="09641b40d6cfd6fece46f1b1578c7425694af966f4aa852ad983e6b8616d3ee7" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2F%3Cuser-name%3E%2F%3Crepo-name%3E%2Fblob%2Fshow&amp;source=header-repo">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# </div>, <div class="d-lg-none css-truncate css-truncate-target width-fit p-2">
# </div>, <div class="d-flex flex-items-center">
# <a class="d-inline-block d-lg-none f5 no-underline border color-border-default rounded-2 px-2 py-1 mr-3 mr-sm-5 color-fg-inherit" data-hydro-click='{"event_type":"authentication.click","payload":{"location_in_page":"site header","repository_id":null,"auth_type":"SIGN_UP","originating_url":"https://github.com/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html","user_id":null}}' data-hydro-click-hmac="09641b40d6cfd6fece46f1b1578c7425694af966f4aa852ad983e6b8616d3ee7" href="/signup?ref_cta=Sign+up&amp;ref_loc=header+logged+out&amp;ref_page=%2F%3Cuser-name%3E%2F%3Crepo-name%3E%2Fblob%2Fshow&amp;source=header-repo">
#               Sign up
#             </a>
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link d-lg-none mt-1 color-fg-inherit" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-three-bars" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M1 2.75A.75.75 0 011.75 2h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 2.75zm0 5A.75.75 0 011.75 7h12.5a.75.75 0 110 1.5H1.75A.75.75 0 011 7.75zM1.75 12a.75.75 0 100 1.5h12.5a.75.75 0 100-1.5H1.75z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>, <div class="HeaderMenu HeaderMenu--logged-out position-fixed top-0 right-0 bottom-0 height-fit position-lg-relative d-lg-flex flex-justify-between flex-items-center flex-auto">
# <div class="d-flex d-lg-none flex-justify-end border-bottom color-bg-subtle p-3">
# <button aria-expanded="false" aria-label="Toggle navigation" class="js-details-target btn-link" data-view-component="true" type="button"> <svg aria-hidden="true" class="octicon octicon-x color-fg-muted" data-view-component="true" height="24" version="1.1" viewbox="0 0 24 24" width="24">
# <path d="M5.72 5.72a.75.75 0 011.06 0L12 10.94l5.22-5.22a.75.75 0 111.06 1.06L13.06 12l5.22 5.22a.75.75 0 11-1.06 1.06L12 13.06l-5.22 5.22a.75.75 0 01-1.06-1.06L10.94 12 5.72 6.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button> </div>
# <nav aria-label="Global" class="mt-0 px-3 px-lg-0 mb-5 mb-lg-0">
# <ul class="d-lg-flex list-style-none">
# <li class="mr-0 mr-lg-3 position-relative flex-wrap flex-justify-between flex-items-center border-bottom border-lg-bottom-0 d-block d-lg-flex flex-lg-nowrap flex-lg-items-center">
# <details class="HeaderMenu-details details-overlay details-reset width-full">
# <summary class="HeaderMenu-summary HeaderMenu-link px-0 py-3 border-0 no-wrap d-block d-lg-inline-block">
#         Product
#         <svg class="icon-chevon-down-mktg position-absolute position-lg-relative" fill="none" viewbox="0 0 14 8" x="0" xml:space="preserve" y="0"><path d="M1,1l6.2,6L13,1"></path></svg>
# </summary>
# <div class="dropdown-menu flex-auto rounded px-0 mt-0 pb-4 p-lg-4 position-relative position-lg-absolute left-0 left-lg-n4">
# <ul class="list-style-none f5 pb-1">
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--primary text-bold py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Features","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Features;"}' href="/features">
#       Features
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Mobile","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Mobile;"}' href="/mobile">
#       Mobile
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Actions","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Actions;"}' href="/features/actions">
#       Actions
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Codespaces","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Codespaces;"}' href="/features/codespaces">
#       Codespaces
# </a> </li>
# <li>
# <a class="lh-condensed-ultra d-block no-underline position-relative Link--secondary py-2" data-analytics-event='{"category":"Header dropdown (logged out), Product","action":"click to go to Copilot","label":"ref_page:/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html;ref_cta:Copilot;"}' href="/features/copilot">
#       Copilot
# </a> </li>
# <li>
# ...
# <svg aria-hidden="true" class="octicon octicon-trash" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M6.5 1.75a.25.25 0 01.25-.25h2.5a.25.25 0 01.25.25V3h-3V1.75zm4.5 0V3h2.25a.75.75 0 010 1.5H2.75a.75.75 0 010-1.5H5V1.75C5 .784 5.784 0 6.75 0h2.5C10.216 0 11 .784 11 1.75zM4.496 6.675a.75.75 0 10-1.492.15l.66 6.6A1.75 1.75 0 005.405 15h5.19c.9 0 1.652-.681 1.741-1.576l.66-6.6a.75.75 0 00-1.492-.149l-.66 6.6a.25.25 0 01-.249.225h-5.19a.25.25 0 01-.249-.225l-.66-6.6z" fill-rule="evenodd"></path>
# </svg>
# </a>
# </div>
# </div>
# <div class="d-flex hide-lg hide-xl flex-order-2 flex-grow-0">
# <details class="dropdown details-reset details-overlay d-inline-block">
# <summary aria-haspopup="true" aria-label="possible actions" class="js-blob-dropdown-click btn-octicon" data-dropdown-tracking='{"type":"blob_edit_dropdown.more_options_click","context":{"repository_id":506742823,"actor_id":null,"github_dev_enabled":false,"edit_enabled":false,"small_screen":true}}' data-test-selector="small-screen-more-options">
# <svg aria-hidden="true" class="octicon octicon-kebab-horizontal" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 9a1.5 1.5 0 100-3 1.5 1.5 0 000 3zM1.5 9a1.5 1.5 0 100-3 1.5 1.5 0 000 3zm13 0a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path>
# </svg>
# </summary>
# <ul class="dropdown-menu dropdown-menu-sw" style="width: 175px">
# <li>
# </li>
# <li>
# <a class="dropdown-item" href="/sipocz/yokodok/raw/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html">
#               Download
#             </a>
# </li>
# </ul>
# </details>
# </div>
# </div>
# <div class="Box-body p-0 blob-wrapper data type-text gist-border-0" itemprop="text">
# <div class="text-center p-3">
# <a href="/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html?raw=true">View raw</a>
# <p>(Sorry about that, but we can’t show files that are this big right now.)</p>
# </div>
# </div>
# </div>, <div class="Box-header js-blob-header py-2 pr-2 d-flex flex-shrink-0 flex-md-row flex-items-center">
# <div class="text-mono f6 flex-auto pr-3 flex-order-2 flex-md-order-1">
#
#     11.2 MB
#   </div>
# <div class="d-flex py-1 py-md-0 flex-auto flex-order-1 flex-md-order-2 flex-sm-grow-0 flex-justify-between hide-sm hide-md">
# <div class="BtnGroup">
# <a class="btn-sm btn BtnGroup-item" data-view-component="true" href="/sipocz/yokodok/raw/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html" id="raw-url">  Download
#
# </a> </div>
# <div class="d-flex">
# <a aria-label="You must be signed in to make or propose changes" class="btn-octicon btn-octicon-danger disabled tooltipped tooltipped-nw" href="/login?return_to=https%3A%2F%2Fgithub.com%2Fsipocz%2Fyokodok%2Fblob%2F1b17d9bd7abe80191a6f6301f828887a437b8e7c%2FLibrary%2520_%2520Yokogawa%2520Electric%2520Corporation.html">
# <svg aria-hidden="true" class="octicon octicon-trash" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M6.5 1.75a.25.25 0 01.25-.25h2.5a.25.25 0 01.25.25V3h-3V1.75zm4.5 0V3h2.25a.75.75 0 010 1.5H2.75a.75.75 0 010-1.5H5V1.75C5 .784 5.784 0 6.75 0h2.5C10.216 0 11 .784 11 1.75zM4.496 6.675a.75.75 0 10-1.492.15l.66 6.6A1.75 1.75 0 005.405 15h5.19c.9 0 1.652-.681 1.741-1.576l.66-6.6a.75.75 0 00-1.492-.149l-.66 6.6a.25.25 0 01-.249.225h-5.19a.25.25 0 01-.249-.225l-.66-6.6z" fill-rule="evenodd"></path>
# </svg>
# </a>
# </div>
# </div>
# <div class="d-flex hide-lg hide-xl flex-order-2 flex-grow-0">
# <details class="dropdown details-reset details-overlay d-inline-block">
# <summary aria-haspopup="true" aria-label="possible actions" class="js-blob-dropdown-click btn-octicon" data-dropdown-tracking='{"type":"blob_edit_dropdown.more_options_click","context":{"repository_id":506742823,"actor_id":null,"github_dev_enabled":false,"edit_enabled":false,"small_screen":true}}' data-test-selector="small-screen-more-options">
# <svg aria-hidden="true" class="octicon octicon-kebab-horizontal" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 9a1.5 1.5 0 100-3 1.5 1.5 0 000 3zM1.5 9a1.5 1.5 0 100-3 1.5 1.5 0 000 3zm13 0a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path>
# </svg>
# </summary>
# <ul class="dropdown-menu dropdown-menu-sw" style="width: 175px">
# <li>
# </li>
# <li>
# <a class="dropdown-item" href="/sipocz/yokodok/raw/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html">
#               Download
#             </a>
# </li>
# </ul>
# </details>
# </div>
# </div>, <div class="text-mono f6 flex-auto pr-3 flex-order-2 flex-md-order-1">
#
#     11.2 MB
#   </div>, <div class="d-flex py-1 py-md-0 flex-auto flex-order-1 flex-md-order-2 flex-sm-grow-0 flex-justify-between hide-sm hide-md">
# <div class="BtnGroup">
# <a class="btn-sm btn BtnGroup-item" data-view-component="true" href="/sipocz/yokodok/raw/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html" id="raw-url">  Download
#
# </a> </div>
# <div class="d-flex">
# <a aria-label="You must be signed in to make or propose changes" class="btn-octicon btn-octicon-danger disabled tooltipped tooltipped-nw" href="/login?return_to=https%3A%2F%2Fgithub.com%2Fsipocz%2Fyokodok%2Fblob%2F1b17d9bd7abe80191a6f6301f828887a437b8e7c%2FLibrary%2520_%2520Yokogawa%2520Electric%2520Corporation.html">
# <svg aria-hidden="true" class="octicon octicon-trash" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M6.5 1.75a.25.25 0 01.25-.25h2.5a.25.25 0 01.25.25V3h-3V1.75zm4.5 0V3h2.25a.75.75 0 010 1.5H2.75a.75.75 0 010-1.5H5V1.75C5 .784 5.784 0 6.75 0h2.5C10.216 0 11 .784 11 1.75zM4.496 6.675a.75.75 0 10-1.492.15l.66 6.6A1.75 1.75 0 005.405 15h5.19c.9 0 1.652-.681 1.741-1.576l.66-6.6a.75.75 0 00-1.492-.149l-.66 6.6a.25.25 0 01-.249.225h-5.19a.25.25 0 01-.249-.225l-.66-6.6z" fill-rule="evenodd"></path>
# </svg>
# </a>
# </div>
# </div>, <div class="BtnGroup">
# <a class="btn-sm btn BtnGroup-item" data-view-component="true" href="/sipocz/yokodok/raw/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html" id="raw-url">  Download
#
# </a> </div>, <div class="d-flex">
# <a aria-label="You must be signed in to make or propose changes" class="btn-octicon btn-octicon-danger disabled tooltipped tooltipped-nw" href="/login?return_to=https%3A%2F%2Fgithub.com%2Fsipocz%2Fyokodok%2Fblob%2F1b17d9bd7abe80191a6f6301f828887a437b8e7c%2FLibrary%2520_%2520Yokogawa%2520Electric%2520Corporation.html">
# <svg aria-hidden="true" class="octicon octicon-trash" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M6.5 1.75a.25.25 0 01.25-.25h2.5a.25.25 0 01.25.25V3h-3V1.75zm4.5 0V3h2.25a.75.75 0 010 1.5H2.75a.75.75 0 010-1.5H5V1.75C5 .784 5.784 0 6.75 0h2.5C10.216 0 11 .784 11 1.75zM4.496 6.675a.75.75 0 10-1.492.15l.66 6.6A1.75 1.75 0 005.405 15h5.19c.9 0 1.652-.681 1.741-1.576l.66-6.6a.75.75 0 00-1.492-.149l-.66 6.6a.25.25 0 01-.249.225h-5.19a.25.25 0 01-.249-.225l-.66-6.6z" fill-rule="evenodd"></path>
# </svg>
# </a>
# </div>, <div class="d-flex hide-lg hide-xl flex-order-2 flex-grow-0">
# <details class="dropdown details-reset details-overlay d-inline-block">
# <summary aria-haspopup="true" aria-label="possible actions" class="js-blob-dropdown-click btn-octicon" data-dropdown-tracking='{"type":"blob_edit_dropdown.more_options_click","context":{"repository_id":506742823,"actor_id":null,"github_dev_enabled":false,"edit_enabled":false,"small_screen":true}}' data-test-selector="small-screen-more-options">
# <svg aria-hidden="true" class="octicon octicon-kebab-horizontal" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8 9a1.5 1.5 0 100-3 1.5 1.5 0 000 3zM1.5 9a1.5 1.5 0 100-3 1.5 1.5 0 000 3zm13 0a1.5 1.5 0 100-3 1.5 1.5 0 000 3z"></path>
# </svg>
# </summary>
# <ul class="dropdown-menu dropdown-menu-sw" style="width: 175px">
# <li>
# </li>
# <li>
# <a class="dropdown-item" href="/sipocz/yokodok/raw/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html">
#               Download
#             </a>
# </li>
# </ul>
# </details>
# </div>, <div class="Box-body p-0 blob-wrapper data type-text gist-border-0" itemprop="text">
# <div class="text-center p-3">
# <a href="/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html?raw=true">View raw</a>
# <p>(Sorry about that, but we can’t show files that are this big right now.)</p>
# </div>
# </div>, <div class="text-center p-3">
# <a href="/sipocz/yokodok/blob/1b17d9bd7abe80191a6f6301f828887a437b8e7c/Library%20_%20Yokogawa%20Electric%20Corporation.html?raw=true">View raw</a>
# <p>(Sorry about that, but we can’t show files that are this big right now.)</p>
# </div>, <div class="position-relative d-flex flex-items-center pb-2 f6 color-fg-muted border-top color-border-muted flex-column-reverse flex-lg-row flex-wrap flex-lg-nowrap mt-6 pt-6">
# <ul class="list-style-none d-flex flex-wrap col-0 col-lg-2 flex-justify-start flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mt-2 mt-lg-0 d-flex flex-items-center">
# <a aria-label="Homepage" class="footer-octicon mr-2" href="https://github.com" title="GitHub">
# <svg aria-hidden="true" class="octicon octicon-mark-github" data-view-component="true" height="24" version="1.1" viewbox="0 0 16 16" width="24">
# <path d="M8 0C3.58 0 0 3.58 0 8c0 3.54 2.29 6.53 5.47 7.59.4.07.55-.17.55-.38 0-.19-.01-.82-.01-1.49-2.01.37-2.53-.49-2.69-.94-.09-.23-.48-.94-.82-1.13-.28-.15-.68-.52-.01-.53.63-.01 1.08.58 1.23.82.72 1.21 1.87.87 2.33.66.07-.52.28-.87.51-1.07-1.78-.2-3.64-.89-3.64-3.95 0-.87.31-1.59.82-2.15-.08-.2-.36-1.02.08-2.12 0 0 .67-.21 2.2.82.64-.18 1.32-.27 2-.27.68 0 1.36.09 2 .27 1.53-1.04 2.2-.82 2.2-.82.44 1.1.16 1.92.08 2.12.51.56.82 1.27.82 2.15 0 3.07-1.87 3.75-3.65 3.95.29.25.54.73.54 1.48 0 1.07-.01 1.93-.01 2.2 0 .21.15.46.55.38A8.013 8.013 0 0016 8c0-4.42-3.58-8-8-8z" fill-rule="evenodd"></path>
# </svg>
# </a> <span>
#         © 2022 GitHub, Inc.
#         </span>
# </li>
# </ul>
# <ul class="list-style-none d-flex flex-wrap col-12 col-lg-8 flex-justify-center flex-lg-justify-between mb-2 mb-lg-0">
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to terms","label":"text:terms"}' href="https://docs.github.com/en/github/site-policy/github-terms-of-service">Terms</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to privacy","label":"text:privacy"}' href="https://docs.github.com/en/github/site-policy/github-privacy-statement">Privacy</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to security","label":"text:security"}' href="https://github.com/security">Security</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to status","label":"text:status"}' href="https://www.githubstatus.com/">Status</a></li>
# <li class="mr-3 mr-lg-0"><a data-ga-click="Footer, go to help, text:Docs" href="https://docs.github.com">Docs</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to contact","label":"text:contact"}' href="https://support.github.com?tags=dotcom-footer">Contact GitHub</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to Pricing","label":"text:Pricing"}' href="https://github.com/pricing">Pricing</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to api","label":"text:api"}' href="https://docs.github.com">API</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to training","label":"text:training"}' href="https://services.github.com">Training</a></li>
# <li class="mr-3 mr-lg-0"><a data-analytics-event='{"category":"Footer","action":"go to blog","label":"text:blog"}' href="https://github.blog">Blog</a></li>
# <li><a data-ga-click="Footer, go to about, text:about" href="https://github.com/about">About</a></li>
# </ul>
# </div>, <div class="d-flex flex-justify-center pb-6">
# <span class="f6 color-fg-muted"></span>
# </div>, <div class="ajax-error-message flash flash-error" hidden="" id="ajax-error-message">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <button aria-label="Dismiss error" class="flash-close js-ajax-error-dismiss" type="button">
# <svg aria-hidden="true" class="octicon octicon-x" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M3.72 3.72a.75.75 0 011.06 0L8 6.94l3.22-3.22a.75.75 0 111.06 1.06L9.06 8l3.22 3.22a.75.75 0 11-1.06 1.06L8 9.06l-3.22 3.22a.75.75 0 01-1.06-1.06L6.94 8 3.72 4.78a.75.75 0 010-1.06z" fill-rule="evenodd"></path>
# </svg>
# </button>
#     You can’t perform that action at this time.
#   </div>, <div class="js-stale-session-flash flash flash-warn flash-banner" hidden="">
# <svg aria-hidden="true" class="octicon octicon-alert" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M8.22 1.754a.25.25 0 00-.44 0L1.698 13.132a.25.25 0 00.22.368h12.164a.25.25 0 00.22-.368L8.22 1.754zm-1.763-.707c.659-1.234 2.427-1.234 3.086 0l6.082 11.378A1.75 1.75 0 0114.082 15H1.918a1.75 1.75 0 01-1.543-2.575L6.457 1.047zM9 11a1 1 0 11-2 0 1 1 0 012 0zm-.25-5.25a.75.75 0 00-1.5 0v2.5a.75.75 0 001.5 0v-2.5z" fill-rule="evenodd"></path>
# </svg>
# <span class="js-stale-session-flash-signed-in" hidden="">You signed in with another tab or window. <a href="">Reload</a> to refresh your session.</span>
# <span class="js-stale-session-flash-signed-out" hidden="">You signed out in another tab or window. <a href="">Reload</a> to refresh your session.</span>
# </div>, <div class="octocat-spinner my-6 js-details-dialog-spinner"></div>, <div class="Popover js-hovercard-content position-absolute" style="display: none; outline: none;" tabindex="0">
# <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>
# </div>, <div class="Popover-message Popover-message--bottom-left Popover-message--large Box color-shadow-large" style="width:360px;">
# </div>, <div class="zeroclipboard-container position-absolute right-0 top-0">
# <clipboard-copy aria-label="Copy" class="ClipboardButton btn js-clipboard-copy m-2 p-0 tooltipped-no-delay" data-copy-feedback="Copied!" data-tooltip-direction="w">
# <svg aria-hidden="true" class="octicon octicon-copy js-clipboard-copy-icon m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M0 6.75C0 5.784.784 5 1.75 5h1.5a.75.75 0 010 1.5h-1.5a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-1.5a.75.75 0 011.5 0v1.5A1.75 1.75 0 019.25 16h-7.5A1.75 1.75 0 010 14.25v-7.5z" fill-rule="evenodd"></path><path d="M5 1.75C5 .784 5.784 0 6.75 0h7.5C15.216 0 16 .784 16 1.75v7.5A1.75 1.75 0 0114.25 11h-7.5A1.75 1.75 0 015 9.25v-7.5zm1.75-.25a.25.25 0 00-.25.25v7.5c0 .138.112.25.25.25h7.5a.25.25 0 00.25-.25v-7.5a.25.25 0 00-.25-.25h-7.5z" fill-rule="evenodd"></path>
# </svg>
# <svg aria-hidden="true" class="octicon octicon-check js-clipboard-check-icon color-fg-success d-none m-2" data-view-component="true" height="16" version="1.1" viewbox="0 0 16 16" width="16">
# <path d="M13.78 4.22a.75.75 0 010 1.06l-7.25 7.25a.75.75 0 01-1.06 0L2.22 9.28a.75.75 0 011.06-1.06L6 10.94l6.72-6.72a.75.75 0 011.06 0z" fill-rule="evenodd"></path>
# </svg>
# </clipboard-copy>
# </div>]
# ----------------  END  ------------------------
